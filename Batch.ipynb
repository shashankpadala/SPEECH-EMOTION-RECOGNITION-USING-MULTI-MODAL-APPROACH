# %%
import numpy as np
import pickle

# %%
path='/content/drive/My Drive/words/'

# %%
import pickle
pickle_off = open ("/content/drive/My Drive/IEMOCAP_full_release/data.pickle", "rb")
emp = pickle.load(pickle_off)
print(emp)
# Out:
# [{'id': 'Ses01F_impro01_F000', 'transcription': 'Excuse me.', 'emotion': 'neu'}, {'id': 'Ses01F_impro01_F001', 'transcription': 'Yeah.', 'emotion': 'neu'}, {'id': 'Ses01F_impro01_F002', 'transcription': 'Is there a problem?', 'emotion': 'neu'}, {'id': 'Ses01F_impro01_F005', 'transcription': "Well what's the problem?  Let me change it.", 'emotion': 'neu'}, {'id': 'Ses01F_impro01_F012', 'transcription': "That's out of control.", 'emotion': 'ang'}, {'id': 'Ses01F_impro01_F014', 'transcription': 'Clearly.  You know, do you have like a supervisor or something?', 'emotion': 'neu'}, {'id': 'Ses01F_impro01_M011', 'transcription': "I don't understand why this is so complicated for people when they get here.  It's just a simple form.  I just need an ID.", 'emotion': 'ang'}, {'id': 'Ses01F_impro01_M013', 'transcription': "Yeah.  Do you want to see my supervisor?  Huh? Yeah.  Do you want to see my supervisor?  Fine.  I'll be right back.", 'emotion': 'ang'}, {'id': 'Ses01F_impro02_F000', 'transcr
# ...

# %%
lst=[]

# %%
for i in range(0,len(emp)):
  lst.append(emp[i]['id'])

# %%
emp[0]['id']
# Out:
# 'Ses01F_impro01_F000'

# %%
import random

# %%
random.shuffle(lst)

# %%
lst[0]
# Out:
# 'Ses03F_impro08_F022'

# %%
train_lst=[]

for i in range(0,4000):
  train_lst.append(lst[i])

# %%
test_lst=[]

# %%
for i in range(4000,4936):
  test_lst.append(lst[i])

# %%
len(test_lst)
# Out:
# 936

# %%
pickling_on = open('/content/drive/My Drive/code/test_data',"wb")
pickle.dump(test_lst, pickling_on)

# %%
pickle_in = open("/content/drive/My Drive/IEMOCAP_full_release/data.pickle","rb")
data = pickle.load(pickle_in)
ids=[]
emo=[]
emotions={}
emotions['neu']=0
emotions['ang']=1
emotions['sad']=2
emotions['exc']=3
for i in data:
  emo.append(emotions[i['emotion']])
  ids.append(i['id'])

# %%
audio_data=[]
for i in range(0,1500):
  aud=np.load('/content/drive/My Drive/preprocessed audio data/'+emp[i]['id']+'.npy')
  audio_data.append(aud)

# %%
for i in range(1500,2500):
  aud=np.load('/content/drive/My Drive/preprocessed audio data/'+emp[i]['id']+'.npy')
  audio_data.append(aud)

# %%
# Out:
# 2500

# %%
for i in range(2500,3500):
  aud=np.load('/content/drive/My Drive/preprocessed audio data/'+emp[i]['id']+'.npy')
  audio_data.append(aud)

# %%
for i in range(3500,4500):
  aud=np.load('/content/drive/My Drive/preprocessed audio data/'+emp[i]['id']+'.npy')
  audio_data.append(aud)

# %%
for i in range(4500,4936):
  aud=np.load('/content/drive/My Drive/preprocessed audio data/'+emp[i]['id']+'.npy')
  audio_data.append(aud)

# %%
len(audio_data)
# Out:
# 4936

# %%
word_data=[]
for i in range(0,500):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 500

# %%
pickling_on = open('/content/drive/My Drive/code/audio_data',"wb")
pickle.dump(audio_data, pickling_on)

# %%
for i in range(500,1000):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 1000

# %%
for i in range(1000,1500):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 1500

# %%
for i in range(1500,2000):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 2000

# %%
for i in range(2000,2500):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 2500

# %%
for i in range(2500,3000):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 3000

# %%
for i in range(3000,3500):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 3500

# %%
for i in range(3500,4000):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 4000

# %%
for i in range(4000,4500):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 4500

# %%
for i in range(4500,4936):
  aud=np.load('/content/drive/My Drive/words/'+emp[i]['id']+'.npy')
  word_data.append(aud)

# %%
len(word_data)
# Out:
# 4936

# %%
pickle_in = open("/content/drive/My Drive/IEMOCAP_full_release/data.pickle","rb")
data1 = pickle.load(pickle_in)
ids=[]
emo=[]
emotions={}
emotions['neu']=0
emotions['ang']=1
emotions['sad']=2
emotions['exc']=3
for i in data1:
  emo.append(emotions[i['emotion']])
  ids.append(i['id'])

# %%
data={'id':lst,'Word_embedding':word_data,'Audio_data':audio_data,'emotion':emo}

# %%
import pandas as pd

# %%
df=pd.DataFrame(data)

# %%
df

# %%
df.to_csv('/content/drive/My Drive/code/dataframe.csv')

# %%
a=df['Word_embedding'][2000]

# %%
cls=a[:,0,:]

# %%
x=df.iloc[:,:]
y=df.iloc[:,3:4]
y

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data,train_lab,test=train_test_split(x,y,test_size=0.1895,random_state=42)

# %%
test_data

# %%
test_data.to_csv('/content/drive/My Drive/code/test_data.csv')

# %%
train_data.to_csv('/content/drive/My Drive/code/train_data.csv')

# %%
num=[]
for i in range(50):
  num.append(str(i))
num

# %%
c=0
for i in range(0,4000,80):
  b=train_data.iloc[i:i+80,:]
  path='/content/drive/My Drive/Batches/batch'+num[c]+'.csv'
  b.to_csv(path)
  c=c+1

# %%
df=pd.read_csv('/content/drive/My Drive/code/train_data.csv')

# %%
df

# %%
a=df['Audio_data']

a[0]

# %%
df.info()

# %%
import numpy as np
type(a[0])
# Out:
# str

# %%
b=a[0].split("\n")
type(b[0].split(" ")[1])
# Out:
# str
