# %%
import numpy as np
import pickle

# %%
data=np.load("/content/drive/My Drive/folds/impro10_train.npy")

# %%
emo=pickle.load(open('/content/drive/My Drive/IEMOCAP_full_release/emotions.pickle',"rb"))
for i in range(1,11):
  print('fold'+str(i))
  ids=np.load('/content/drive/My Drive/folds/impro'+str(i)+'_train.npy')
  x_train=[]
  y_train=[]
  ids=list(ids)
  for id in ids:
    print(id)
    audio=np.load('/content/drive/My Drive/preprocessed audio data/'+id+'.npy')
    text=np.load('/content/drive/My Drive/words/'+id+'.npy')
    data=[audio,text]
    x_train.append(data)
    y_train.append(emo[id])
  pickle.dump(x_train,open('/content/drive/My Drive/data/impro'+str(i)+'trainx.pickle','wb'))
  pickle.dump(y_train,open('/content/drive/My Drive/data/impro'+str(i)+'trainy.pickle','wb'))

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/data/impro1trainx.pickle','rb'))
y[1000][0].shape[1]
# Out:
# 432

# %%
str(data[0])
type(data[0])
# Out:
# numpy.str_

# %%
import pickle
import numpy as np

train=[]
for j in range(4,5):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/4trainx.pickle','rb'))
len(y)
# Out:
# 2183

# %%
import pickle
import numpy as np

train=[]
for j in range(1,2):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/5trainx.pickle','rb'))
len(y)
# Out:
# 2092

# %%
import pickle
import numpy as np

train=[]
for j in range(2,3):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/6trainx.pickle','rb'))
len(y)
# Out:
# 2092

# %%
import pickle
import numpy as np

train=[]
for j in range(3,4):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/7trainx.pickle','rb'))
len(y)
# Out:
# 2156

# %%
import pickle
import numpy as np

train=[]
for j in range(5,6):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/8trainx.pickle','rb'))
len(y)
# Out:
# 2156

# %%
import pickle
import numpy as np

train=[]
for j in range(6,7):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/9trainx.pickle','rb'))
len(y)
# Out:
# 2034

# %%
import pickle
import numpy as np

train=[]
for j in range(7,8):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
y=pickle.load(open('/content/drive/My Drive/practice/padded_impro/10trainx.pickle','rb'))
len(y)
# Out:
# 2034

# %%
audio_data.shape[1]
# Out:
# 994

# %%
import pickle
import numpy as np

train=[]
for j in range(8,9):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
import numpy as np

train=[]
for j in range(9,10):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")

# %%
import pickle
import numpy as np

train=[]
for j in range(10,11):
  print("j th file",j)
  data=pickle.load(open('/content/drive/My Drive/data/impro'+str(j)+'trainx.pickle','rb'))
  c=0
  for l1 in range(0,len(data),30):
    print("l",l1)
    max=0
    for k1 in range(l1,l1+30):
      c=c+1
      if(k1>=len(data)):
        break
      audio_data=data[k1]
      max1=audio_data[0].shape[1]
      print(max1)
      if(max<max1):
        max=max1
    print("Maximum is:",max)
    d=0
    for i in range(l1,l1+30):
      print("In files:",d)
      d=d+1
      if(i>=len(data)):
        break
      audio_data=data[i]
      lst=[]
      for k in range(0,38):
        col_add=[]
        for l in range(audio_data[0].shape[1],max):
          col_add.append(0)
        lst.append(col_add)
      lst.append(col_add)
      lst1=np.array(lst)
      print("lst",lst1.shape)
      aud = np.concatenate((audio_data[0], lst1), axis=1)
      print("shape after",aud.shape)
      data[i][0]=aud
    pickle.dump(data,open('/content/drive/My Drive/practice/padded_impro/'+str(j)+'trainx.pickle','wb'))

print("DONE")
